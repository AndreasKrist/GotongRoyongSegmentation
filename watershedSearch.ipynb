# %%
import os
import itertools
import cv2
import numpy as np
import pandas as pd
from sklearn.metrics import precision_score, recall_score, f1_score, jaccard_score

class WatershedParameterExplorer:
    def __init__(self, images_dir, masks_dir):
        """
        Initialize explorer with image and mask directories
        
        Parameters:
        images_dir (str): Directory containing input images
        masks_dir (str): Directory containing ground truth masks
        """
        self.images_dir = images_dir
        self.masks_dir = masks_dir
        
        # Load image and mask pairs
        self.image_files = sorted([f for f in os.listdir(images_dir) if f.endswith(('.jpg', '.png', '.jpeg'))])
        self.mask_files = sorted([f for f in os.listdir(masks_dir) if f.endswith(('.jpg', '.png', '.jpeg'))])
        
        # Validate image-mask pairs
        assert len(self.image_files) == len(self.mask_files), \
            "Number of images and masks must be the same"
        
        # Limit to first 100 images if more exist
        self.image_files = self.image_files[:100]
        self.mask_files = self.mask_files[:100]
    
    def watershed_segmentation(self, image, blur_kernel, custom_thresh, morph_kernel, dilate_iter):
        """
        Perform watershed segmentation with given parameters
        
        Returns:
        numpy.ndarray: Segmented image
        """
        # Convert to odd kernel size
        blur_kernel_size = (blur_kernel * 2 + 1, blur_kernel * 2 + 1)
        
        # Grayscale conversion
        gray = cv2.cvtColor(image, cv2.COLOR_BGR2GRAY)
        
        # Gaussian blur
        blurred = cv2.GaussianBlur(gray, blur_kernel_size, 0)
        
        # Binary thresholding
        _, thresh = cv2.threshold(blurred, custom_thresh, 255, cv2.THRESH_BINARY)
        
        # Morphological kernel
        kernel = np.ones((morph_kernel, morph_kernel), np.uint8)
        
        # Morphological opening
        opening = cv2.morphologyEx(thresh, cv2.MORPH_OPEN, kernel, iterations=1)
        
        # Dilation
        dilated = cv2.dilate(opening, kernel, iterations=dilate_iter)
        
        # Distance transform
        dist_transform = cv2.distanceTransform(dilated, cv2.DIST_L2, 5)
        
        # Foreground threshold
        _, sure_fg = cv2.threshold(dist_transform, 0.5*dist_transform.max(), 255, 0)
        sure_fg = sure_fg.astype(np.uint8)
        
        # Connected components
        _, markers = cv2.connectedComponents(sure_fg)
        
        # Watershed preparation
        markers = markers + 1
        markers[sure_fg == 0] = 0
        
        # Create result image
        result = image.copy()
        cv2.watershed(result, markers)
        
        # Create binary segmentation
        segmented = np.zeros_like(gray)
        segmented[markers == -1] = 255
        
        return segmented
    
    def calculate_metrics(self, ground_truth, prediction):
        """
        Calculate segmentation metrics
        
        Returns:
        dict: Metrics including precision, recall, F1, and Jaccard
        """
        # Ensure binary images
        gt_binary = (ground_truth > 0).astype(int).ravel()
        pred_binary = (prediction > 0).astype(int).ravel()
        
        return {
            'precision': precision_score(gt_binary, pred_binary, zero_division=0),
            'recall': recall_score(gt_binary, pred_binary, zero_division=0),
            'f1_score': f1_score(gt_binary, pred_binary, zero_division=0),
            'jaccard': jaccard_score(gt_binary, pred_binary, zero_division=0)
        }
    
    def generate_parameter_combinations(self):
        """
        Automatically generate parameter combinations
        
        Returns:
        list: List of parameter dictionaries
        """
        # Define parameter ranges
        blur_kernels = [1, 3, 5, 7, 9]
        custom_thresholds = [50, 100, 127, 150, 200]
        morph_kernels = [3, 5, 7]
        dilate_iterations = [1, 2, 3]
        
        # Generate all combinations
        parameter_combinations = list(itertools.product(
            blur_kernels,
            custom_thresholds,
            morph_kernels,
            dilate_iterations
        ))
        
        # Convert to list of dictionaries
        parameter_sets = [
            {
                'blur_kernel': combo[0],
                'custom_thresh': combo[1],
                'morph_kernel': combo[2],
                'dilate_iter': combo[3]
            }
            for combo in parameter_combinations
        ]
        
        return parameter_sets
    
    def explore_parameters(self, parameter_sets):
        """
        Explore multiple parameter sets across all images
        
        Parameters:
        parameter_sets (list): List of parameter dictionaries to test
        
        Returns:
        pandas.DataFrame: Average metrics for each parameter set
        """
        # Results storage
        results = []
        
        # Total combinations for progress tracking
        total_combinations = len(parameter_sets)
        
        # Iterate through parameter sets
        for idx, params in enumerate(parameter_sets, 1):
            # Metrics for this parameter set
            set_metrics = []
            
            # Process all images
            for image_file, mask_file in zip(self.image_files, self.mask_files):
                # Read image and mask
                image = cv2.imread(os.path.join(self.images_dir, image_file))
                mask = cv2.imread(os.path.join(self.masks_dir, mask_file), cv2.IMREAD_GRAYSCALE)
                
                # Perform segmentation
                segmented = self.watershed_segmentation(
                    image, 
                    params['blur_kernel'], 
                    params['custom_thresh'], 
                    params['morph_kernel'], 
                    params['dilate_iter']
                )
                
                # Calculate metrics
                metrics = self.calculate_metrics(mask, segmented)
                set_metrics.append(metrics)
            
            # Calculate average metrics for this parameter set
            avg_metrics = {
                metric: np.mean([m[metric] for m in set_metrics])
                for metric in ['precision', 'recall', 'f1_score', 'jaccard']
            }
            
            # Store results with parameters
            result = {**params, **avg_metrics}
            results.append(result)
            
            # Progress tracking
            print(f"\nProcessing Combination {idx}/{total_combinations}")
            print(f"Parameters: {params}")
            for metric, value in avg_metrics.items():
                print(f"  {metric.replace('_', ' ').title()}: {value:.4f}")
        
        # Convert to DataFrame
        results_df = pd.DataFrame(results)
        
        # Sort by F1 score in descending order
        results_df = results_df.sort_values('f1_score', ascending=False)
        
        return results_df

def main():
    # Directories for images and ground truth masks
    images_dir = 'images/'
    masks_dir = 'masks/'
    
    # Create explorer
    explorer = WatershedParameterExplorer(images_dir, masks_dir)
    
    # Generate parameter combinations
    parameter_sets = explorer.generate_parameter_combinations()
    
    print(f"Total parameter combinations to explore: {len(parameter_sets)}")
    
    # Explore parameters
    results_df = explorer.explore_parameters(parameter_sets)
    
    # Save results to CSV
    results_df.to_csv('watershed_parameter_exploration.csv', index=False)
    
    # Print top 10 best parameter configurations
    print("\n--- Top 10 Best Parameter Configurations ---")
    print(results_df.head(10).to_string(index=False))
    
    # Print best parameter configuration
    best_params = results_df.iloc[0]
    print("\n--- Best Overall Parameter Configuration ---")
    print("Blur Kernel:", best_params['blur_kernel'])
    print("Custom Threshold:", best_params['custom_thresh'])
    print("Morph Kernel:", best_params['morph_kernel'])
    print("Dilate Iterations:", best_params['dilate_iter'])
    print("\nMetrics:")
    for metric in ['precision', 'recall', 'f1_score', 'jaccard']:
        print(f"  {metric.replace('_', ' ').title()}: {best_params[metric]:.4f}")

if __name__ == '__main__':
    main()
# Out:
# Total parameter combinations to explore: 225
#
# Processing Combination 1/225
# Parameters: {'blur_kernel': 1, 'custom_thresh': 50, 'morph_kernel': 3, 'dilate_iter': 1}
#   Precision: 0.0128
#   Recall: 0.0035
#   F1 Score: 0.0053
#   Jaccard: 0.0026
#
# Processing Combination 2/225
# Parameters: {'blur_kernel': 1, 'custom_thresh': 50, 'morph_kernel': 3, 'dilate_iter': 2}
#   Precision: 0.0128
#   Recall: 0.0035
#   F1 Score: 0.0053
#   Jaccard: 0.0026
#
# Processing Combination 3/225
# Parameters: {'blur_kernel': 1, 'custom_thresh': 50, 'morph_kernel': 3, 'dilate_iter': 3}
#   Precision: 0.0128
#   Recall: 0.0035
#   F1 Score: 0.0053
#   Jaccard: 0.0026
#
# Processing Combination 4/225
# Parameters: {'blur_kernel': 1, 'custom_thresh': 50, 'morph_kernel': 5, 'dilate_iter': 1}
#   Precision: 0.0128
#   Recall: 0.0035
#   F1 Score: 0.0053
#   Jaccard: 0.0026
#
# Processing Combination 5/225
# Parameters: {'blur_kernel': 1, 'custom_thresh': 50, 'morph_kernel': 5, 'dilate_iter': 2}
#   Precision: 0.0128
#   Recall: 0.0035
#   F1 Score: 0.0053
#   Jaccard: 0.0026
#
# Processing Combination 6/225
# Parameters: {'blur_kernel': 1, 'custom_thresh': 50, 'morph_kernel': 5, 'dilate_iter': 3}
#   Precision: 0.0128
#   Recall: 0.0035
#   F1 Score: 0.0053
#   Jaccard: 0.0026
#
# Processing Combination 7/225
# Parameters: {'blur_kernel': 1, 'custom_thresh': 50, 'morph_kernel': 7, 'dilate_iter': 1}
#   Precision: 0.0128
#   Recall: 0.0035
#   F1 Score: 0.0053
#   Jaccard: 0.0026
#
# Processing Combination 8/225
# Parameters: {'blur_kernel': 1, 'custom_thresh': 50, 'morph_kernel': 7, 'dilate_iter': 2}
#   Precision: 0.0128
#   Recall: 0.0035
#   F1 Score: 0.0053
#   Jaccard: 0.0026
#
# Processing Combination 9/225
# Parameters: {'blur_kernel': 1, 'custom_thresh': 50, 'morph_kernel': 7, 'dilate_iter': 3}
#   Precision: 0.0128
#   Recall: 0.0035
#   F1 Score: 0.0053
#   Jaccard: 0.0026
#
# Processing Combination 10/225
# Parameters: {'blur_kernel': 1, 'custom_thresh': 100, 'morph_kernel': 3, 'dilate_iter': 1}
#   Precision: 0.0825
#   Recall: 0.0379
#   F1 Score: 0.0508
#   Jaccard: 0.0268
#
# Processing Combination 11/225
# Parameters: {'blur_kernel': 1, 'custom_thresh': 100, 'morph_kernel': 3, 'dilate_iter': 2}
#   Precision: 0.0520
#   Recall: 0.0212
#   F1 Score: 0.0290
#   Jaccard: 0.0151
#
# Processing Combination 12/225
# Parameters: {'blur_kernel': 1, 'custom_thresh': 100, 'morph_kernel': 3, 'dilate_iter': 3}
#   Precision: 0.0312
#   Recall: 0.0111
#   F1 Score: 0.0156
#   Jaccard: 0.0081
#
# Processing Combination 13/225
# Parameters: {'blur_kernel': 1, 'custom_thresh': 100, 'morph_kernel': 5, 'dilate_iter': 1}
#   Precision: 0.0508
#   Recall: 0.0217
#   F1 Score: 0.0292
#   Jaccard: 0.0153
#
# Processing Combination 14/225
# Parameters: {'blur_kernel': 1, 'custom_thresh': 100, 'morph_kernel': 5, 'dilate_iter': 2}
#   Precision: 0.0229
#   Recall: 0.0079
#   F1 Score: 0.0110
#   Jaccard: 0.0057
#
# Processing Combination 15/225
# Parameters: {'blur_kernel': 1, 'custom_thresh': 100, 'morph_kernel': 5, 'dilate_iter': 3}
#   Precision: 0.0151
#   Recall: 0.0044
#   F1 Score: 0.0065
#   Jaccard: 0.0033
#
# Processing Combination 16/225
# Parameters: {'blur_kernel': 1, 'custom_thresh': 100, 'morph_kernel': 7, 'dilate_iter': 1}
#   Precision: 0.0424
#   Recall: 0.0163
#   F1 Score: 0.0224
#   Jaccard: 0.0117
#
# Processing Combination 17/225
# Parameters: {'blur_kernel': 1, 'custom_thresh': 100, 'morph_kernel': 7, 'dilate_iter': 2}
#   Precision: 0.0139
#   Recall: 0.0041
#   F1 Score: 0.0061
#   Jaccard: 0.0031
#
# Processing Combination 18/225
# Parameters: {'blur_kernel': 1, 'custom_thresh': 100, 'morph_kernel': 7, 'dilate_iter': 3}
#   Precision: 0.0129
#   Recall: 0.0036
#   F1 Score: 0.0054
#   Jaccard: 0.0027
#
# Processing Combination 19/225
# Parameters: {'blur_kernel': 1, 'custom_thresh': 127, 'morph_kernel': 3, 'dilate_iter': 1}
#   Precision: 0.0852
#   Recall: 0.0753
#   F1 Score: 0.0732
#   Jaccard: 0.0383
#
# Processing Combination 20/225
# Parameters: {'blur_kernel': 1, 'custom_thresh': 127, 'morph_kernel': 3, 'dilate_iter': 2}
#   Precision: 0.0816
#   Recall: 0.0548
#   F1 Score: 0.0611
#   Jaccard: 0.0321
#
# Processing Combination 21/225
# Parameters: {'blur_kernel': 1, 'custom_thresh': 127, 'morph_kernel': 3, 'dilate_iter': 3}
#   Precision: 0.0841
#   Recall: 0.0507
#   F1 Score: 0.0604
#   Jaccard: 0.0318
#
# Processing Combination 22/225
# Parameters: {'blur_kernel': 1, 'custom_thresh': 127, 'morph_kernel': 5, 'dilate_iter': 1}
#   Precision: 0.0887
#   Recall: 0.0627
#   F1 Score: 0.0683
#   Jaccard: 0.0358
#
# Processing Combination 23/225
# Parameters: {'blur_kernel': 1, 'custom_thresh': 127, 'morph_kernel': 5, 'dilate_iter': 2}
#   Precision: 0.0659
#   Recall: 0.0417
#   F1 Score: 0.0476
#   Jaccard: 0.0249
#
# Processing Combination 24/225
# Parameters: {'blur_kernel': 1, 'custom_thresh': 127, 'morph_kernel': 5, 'dilate_iter': 3}
#   Precision: 0.0536
#   Recall: 0.0317
#   F1 Score: 0.0371
#   Jaccard: 0.0194
#
# Processing Combination 25/225
# Parameters: {'blur_kernel': 1, 'custom_thresh': 127, 'morph_kernel': 7, 'dilate_iter': 1}
#   Precision: 0.0803
#   Recall: 0.0512
#   F1 Score: 0.0585
#   Jaccard: 0.0307
#
# Processing Combination 26/225
# Parameters: {'blur_kernel': 1, 'custom_thresh': 127, 'morph_kernel': 7, 'dilate_iter': 2}
#   Precision: 0.0614
#   Recall: 0.0353
#   F1 Score: 0.0422
#   Jaccard: 0.0220
#
# Processing Combination 27/225
# Parameters: {'blur_kernel': 1, 'custom_thresh': 127, 'morph_kernel': 7, 'dilate_iter': 3}
#   Precision: 0.0451
#   Recall: 0.0241
#   F1 Score: 0.0296
#   Jaccard: 0.0154
#
# Processing Combination 28/225
# Parameters: {'blur_kernel': 1, 'custom_thresh': 150, 'morph_kernel': 3, 'dilate_iter': 1}
#   Precision: 0.0567
#   Recall: 0.0425
#   F1 Score: 0.0429
#   Jaccard: 0.0223
#
# Processing Combination 29/225
# Parameters: {'blur_kernel': 1, 'custom_thresh': 150, 'morph_kernel': 3, 'dilate_iter': 2}
#   Precision: 0.0648
#   Recall: 0.0470
#   F1 Score: 0.0495
#   Jaccard: 0.0259
#
# Processing Combination 30/225
# Parameters: {'blur_kernel': 1, 'custom_thresh': 150, 'morph_kernel': 3, 'dilate_iter': 3}
#   Precision: 0.0679
#   Recall: 0.0477
#   F1 Score: 0.0515
#   Jaccard: 0.0269
#
# Processing Combination 31/225
# Parameters: {'blur_kernel': 1, 'custom_thresh': 150, 'morph_kernel': 5, 'dilate_iter': 1}
#   Precision: 0.0361
#   Recall: 0.0227
#   F1 Score: 0.0243
#   Jaccard: 0.0126
#
# Processing Combination 32/225
# Parameters: {'blur_kernel': 1, 'custom_thresh': 150, 'morph_kernel': 5, 'dilate_iter': 2}
#   Precision: 0.0406
#   Recall: 0.0244
#   F1 Score: 0.0274
#   Jaccard: 0.0143
#
# Processing Combination 33/225
# Parameters: {'blur_kernel': 1, 'custom_thresh': 150, 'morph_kernel': 5, 'dilate_iter': 3}
#   Precision: 0.0373
#   Recall: 0.0217
#   F1 Score: 0.0256
#   Jaccard: 0.0133
#
# Processing Combination 34/225
# Parameters: {'blur_kernel': 1, 'custom_thresh': 150, 'morph_kernel': 7, 'dilate_iter': 1}
#   Precision: 0.0352
#   Recall: 0.0201
#   F1 Score: 0.0228
#   Jaccard: 0.0119
#
# Processing Combination 35/225
# Parameters: {'blur_kernel': 1, 'custom_thresh': 150, 'morph_kernel': 7, 'dilate_iter': 2}
#   Precision: 0.0339
#   Recall: 0.0188
#   F1 Score: 0.0217
#   Jaccard: 0.0113
#
# Processing Combination 36/225
# Parameters: {'blur_kernel': 1, 'custom_thresh': 150, 'morph_kernel': 7, 'dilate_iter': 3}
#   Precision: 0.0306
#   Recall: 0.0172
#   F1 Score: 0.0200
#   Jaccard: 0.0104
#
# Processing Combination 37/225
# Parameters: {'blur_kernel': 1, 'custom_thresh': 200, 'morph_kernel': 3, 'dilate_iter': 1}
#   Precision: 0.0131
#   Recall: 0.0037
#   F1 Score: 0.0055
#   Jaccard: 0.0028
#
# Processing Combination 38/225
# Parameters: {'blur_kernel': 1, 'custom_thresh': 200, 'morph_kernel': 3, 'dilate_iter': 2}
#   Precision: 0.0131
#   Recall: 0.0037
#   F1 Score: 0.0055
#   Jaccard: 0.0028
#
# Processing Combination 39/225
# Parameters: {'blur_kernel': 1, 'custom_thresh': 200, 'morph_kernel': 3, 'dilate_iter': 3}
#   Precision: 0.0140
#   Recall: 0.0041
#   F1 Score: 0.0061
#   Jaccard: 0.0031
#
# Processing Combination 40/225
# Parameters: {'blur_kernel': 1, 'custom_thresh': 200, 'morph_kernel': 5, 'dilate_iter': 1}
#   Precision: 0.0128
#   Recall: 0.0035
#   F1 Score: 0.0053
#   Jaccard: 0.0026
#
# Processing Combination 41/225
# Parameters: {'blur_kernel': 1, 'custom_thresh': 200, 'morph_kernel': 5, 'dilate_iter': 2}
#   Precision: 0.0128
#   Recall: 0.0035
#   F1 Score: 0.0053
#   Jaccard: 0.0026
#
# Processing Combination 42/225
# Parameters: {'blur_kernel': 1, 'custom_thresh': 200, 'morph_kernel': 5, 'dilate_iter': 3}
#   Precision: 0.0128
#   Recall: 0.0035
#   F1 Score: 0.0053
#   Jaccard: 0.0026
#
# Processing Combination 43/225
# Parameters: {'blur_kernel': 1, 'custom_thresh': 200, 'morph_kernel': 7, 'dilate_iter': 1}
#   Precision: 0.0128
#   Recall: 0.0035
#   F1 Score: 0.0053
#   Jaccard: 0.0026
#
# Processing Combination 44/225
# Parameters: {'blur_kernel': 1, 'custom_thresh': 200, 'morph_kernel': 7, 'dilate_iter': 2}
#   Precision: 0.0128
#   Recall: 0.0035
#   F1 Score: 0.0053
#   Jaccard: 0.0026
#
# Processing Combination 45/225
# Parameters: {'blur_kernel': 1, 'custom_thresh': 200, 'morph_kernel': 7, 'dilate_iter': 3}
#   Precision: 0.0128
#   Recall: 0.0035
#   F1 Score: 0.0053
#   Jaccard: 0.0026
#
# Processing Combination 46/225
# Parameters: {'blur_kernel': 3, 'custom_thresh': 50, 'morph_kernel': 3, 'dilate_iter': 1}
#   Precision: 0.0128
#   Recall: 0.0035
#   F1 Score: 0.0053
#   Jaccard: 0.0026
#
# Processing Combination 47/225
# Parameters: {'blur_kernel': 3, 'custom_thresh': 50, 'morph_kernel': 3, 'dilate_iter': 2}
#   Precision: 0.0128
#   Recall: 0.0035
#   F1 Score: 0.0053
#   Jaccard: 0.0026
#
# Processing Combination 48/225
# Parameters: {'blur_kernel': 3, 'custom_thresh': 50, 'morph_kernel': 3, 'dilate_iter': 3}
#   Precision: 0.0128
#   Recall: 0.0035
#   F1 Score: 0.0053
#   Jaccard: 0.0026
#
# Processing Combination 49/225
# Parameters: {'blur_kernel': 3, 'custom_thresh': 50, 'morph_kernel': 5, 'dilate_iter': 1}
#   Precision: 0.0128
#   Recall: 0.0035
#   F1 Score: 0.0053
#   Jaccard: 0.0026
#
# Processing Combination 50/225
# Parameters: {'blur_kernel': 3, 'custom_thresh': 50, 'morph_kernel': 5, 'dilate_iter': 2}
#   Precision: 0.0128
#   Recall: 0.0035
#   F1 Score: 0.0053
#   Jaccard: 0.0026
#
# Processing Combination 51/225
# Parameters: {'blur_kernel': 3, 'custom_thresh': 50, 'morph_kernel': 5, 'dilate_iter': 3}
#   Precision: 0.0128
#   Recall: 0.0035
#   F1 Score: 0.0053
#   Jaccard: 0.0026
#
# Processing Combination 52/225
# Parameters: {'blur_kernel': 3, 'custom_thresh': 50, 'morph_kernel': 7, 'dilate_iter': 1}
#   Precision: 0.0128
#   Recall: 0.0035
#   F1 Score: 0.0053
#   Jaccard: 0.0026
#
# Processing Combination 53/225
# Parameters: {'blur_kernel': 3, 'custom_thresh': 50, 'morph_kernel': 7, 'dilate_iter': 2}
#   Precision: 0.0128
#   Recall: 0.0035
#   F1 Score: 0.0053
#   Jaccard: 0.0026
#
# Processing Combination 54/225
# Parameters: {'blur_kernel': 3, 'custom_thresh': 50, 'morph_kernel': 7, 'dilate_iter': 3}
#   Precision: 0.0128
#   Recall: 0.0035
#   F1 Score: 0.0053
#   Jaccard: 0.0026
#
# Processing Combination 55/225
# Parameters: {'blur_kernel': 3, 'custom_thresh': 100, 'morph_kernel': 3, 'dilate_iter': 1}
#   Precision: 0.0723
#   Recall: 0.0311
#   F1 Score: 0.0422
#   Jaccard: 0.0222
#
# Processing Combination 56/225
# Parameters: {'blur_kernel': 3, 'custom_thresh': 100, 'morph_kernel': 3, 'dilate_iter': 2}
#   Precision: 0.0467
#   Recall: 0.0184
#   F1 Score: 0.0254
#   Jaccard: 0.0133
#
# Processing Combination 57/225
# Parameters: {'blur_kernel': 3, 'custom_thresh': 100, 'morph_kernel': 3, 'dilate_iter': 3}
#   Precision: 0.0293
#   Recall: 0.0108
#   F1 Score: 0.0152
#   Jaccard: 0.0079
#
# Processing Combination 58/225
# Parameters: {'blur_kernel': 3, 'custom_thresh': 100, 'morph_kernel': 5, 'dilate_iter': 1}
#   Precision: 0.0482
#   Recall: 0.0190
#   F1 Score: 0.0262
#   Jaccard: 0.0137
#
# Processing Combination 59/225
# Parameters: {'blur_kernel': 3, 'custom_thresh': 100, 'morph_kernel': 5, 'dilate_iter': 2}
#   Precision: 0.0206
#   Recall: 0.0065
#   F1 Score: 0.0094
#   Jaccard: 0.0048
#
# Processing Combination 60/225
# Parameters: {'blur_kernel': 3, 'custom_thresh': 100, 'morph_kernel': 5, 'dilate_iter': 3}
#   Precision: 0.0147
#   Recall: 0.0040
#   F1 Score: 0.0060
#   Jaccard: 0.0030
#
# Processing Combination 61/225
# Parameters: {'blur_kernel': 3, 'custom_thresh': 100, 'morph_kernel': 7, 'dilate_iter': 1}
#   Precision: 0.0339
#   Recall: 0.0128
#   F1 Score: 0.0177
#   Jaccard: 0.0092
#
# Processing Combination 62/225
# Parameters: {'blur_kernel': 3, 'custom_thresh': 100, 'morph_kernel': 7, 'dilate_iter': 2}
#   Precision: 0.0133
#   Recall: 0.0037
#   F1 Score: 0.0055
#   Jaccard: 0.0028
#
# Processing Combination 63/225
# Parameters: {'blur_kernel': 3, 'custom_thresh': 100, 'morph_kernel': 7, 'dilate_iter': 3}
#   Precision: 0.0128
#   Recall: 0.0035
#   F1 Score: 0.0053
#   Jaccard: 0.0026
#
# Processing Combination 64/225
# Parameters: {'blur_kernel': 3, 'custom_thresh': 127, 'morph_kernel': 3, 'dilate_iter': 1}
#   Precision: 0.0868
#   Recall: 0.0684
#   F1 Score: 0.0708
#   Jaccard: 0.0371
#
# Processing Combination 65/225
# Parameters: {'blur_kernel': 3, 'custom_thresh': 127, 'morph_kernel': 3, 'dilate_iter': 2}
#   Precision: 0.0856
#   Recall: 0.0553
#   F1 Score: 0.0625
#   Jaccard: 0.0329
#
# Processing Combination 66/225
# Parameters: {'blur_kernel': 3, 'custom_thresh': 127, 'morph_kernel': 3, 'dilate_iter': 3}
#   Precision: 0.0758
#   Recall: 0.0452
#   F1 Score: 0.0539
#   Jaccard: 0.0283
#
# Processing Combination 67/225
# Parameters: {'blur_kernel': 3, 'custom_thresh': 127, 'morph_kernel': 5, 'dilate_iter': 1}
#   Precision: 0.0884
#   Recall: 0.0569
#   F1 Score: 0.0656
#   Jaccard: 0.0345
#
# Processing Combination 68/225
# Parameters: {'blur_kernel': 3, 'custom_thresh': 127, 'morph_kernel': 5, 'dilate_iter': 2}
#   Precision: 0.0670
#   Recall: 0.0403
#   F1 Score: 0.0473
#   Jaccard: 0.0248
#
# Processing Combination 69/225
# Parameters: {'blur_kernel': 3, 'custom_thresh': 127, 'morph_kernel': 5, 'dilate_iter': 3}
#   Precision: 0.0538
#   Recall: 0.0298
#   F1 Score: 0.0363
#   Jaccard: 0.0190
#
# Processing Combination 70/225
# Parameters: {'blur_kernel': 3, 'custom_thresh': 127, 'morph_kernel': 7, 'dilate_iter': 1}
#   Precision: 0.0852
#   Recall: 0.0501
#   F1 Score: 0.0600
#   Jaccard: 0.0316
#
# Processing Combination 71/225
# Parameters: {'blur_kernel': 3, 'custom_thresh': 127, 'morph_kernel': 7, 'dilate_iter': 2}
#   Precision: 0.0566
#   Recall: 0.0304
#   F1 Score: 0.0371
#   Jaccard: 0.0194
#
# Processing Combination 72/225
# Parameters: {'blur_kernel': 3, 'custom_thresh': 127, 'morph_kernel': 7, 'dilate_iter': 3}
#   Precision: 0.0439
#   Recall: 0.0229
#   F1 Score: 0.0284
#   Jaccard: 0.0148
#
# Processing Combination 73/225
# Parameters: {'blur_kernel': 3, 'custom_thresh': 150, 'morph_kernel': 3, 'dilate_iter': 1}
#   Precision: 0.0536
#   Recall: 0.0368
#   F1 Score: 0.0384
#   Jaccard: 0.0200
#
# Processing Combination 74/225
# Parameters: {'blur_kernel': 3, 'custom_thresh': 150, 'morph_kernel': 3, 'dilate_iter': 2}
#   Precision: 0.0623
#   Recall: 0.0399
#   F1 Score: 0.0445
#   Jaccard: 0.0233
#
# Processing Combination 75/225
# Parameters: {'blur_kernel': 3, 'custom_thresh': 150, 'morph_kernel': 3, 'dilate_iter': 3}
#   Precision: 0.0617
#   Recall: 0.0384
#   F1 Score: 0.0433
#   Jaccard: 0.0226
#
# Processing Combination 76/225
# Parameters: {'blur_kernel': 3, 'custom_thresh': 150, 'morph_kernel': 5, 'dilate_iter': 1}
#   Precision: 0.0398
#   Recall: 0.0246
#   F1 Score: 0.0272
#   Jaccard: 0.0141
#
# Processing Combination 77/225
# Parameters: {'blur_kernel': 3, 'custom_thresh': 150, 'morph_kernel': 5, 'dilate_iter': 2}
#   Precision: 0.0447
#   Recall: 0.0236
#   F1 Score: 0.0287
#   Jaccard: 0.0150
#
# Processing Combination 78/225
# Parameters: {'blur_kernel': 3, 'custom_thresh': 150, 'morph_kernel': 5, 'dilate_iter': 3}
#   Precision: 0.0417
#   Recall: 0.0231
#   F1 Score: 0.0280
#   Jaccard: 0.0146
#
# Processing Combination 79/225
# Parameters: {'blur_kernel': 3, 'custom_thresh': 150, 'morph_kernel': 7, 'dilate_iter': 1}
#   Precision: 0.0369
#   Recall: 0.0211
#   F1 Score: 0.0240
#   Jaccard: 0.0125
#
# Processing Combination 80/225
# Parameters: {'blur_kernel': 3, 'custom_thresh': 150, 'morph_kernel': 7, 'dilate_iter': 2}
#   Precision: 0.0355
#   Recall: 0.0186
#   F1 Score: 0.0224
#   Jaccard: 0.0116
#
# Processing Combination 81/225
# Parameters: {'blur_kernel': 3, 'custom_thresh': 150, 'morph_kernel': 7, 'dilate_iter': 3}
#   Precision: 0.0335
#   Recall: 0.0170
#   F1 Score: 0.0208
#   Jaccard: 0.0108
#
# Processing Combination 82/225
# Parameters: {'blur_kernel': 3, 'custom_thresh': 200, 'morph_kernel': 3, 'dilate_iter': 1}
#   Precision: 0.0128
#   Recall: 0.0035
#   F1 Score: 0.0053
#   Jaccard: 0.0026
#
# Processing Combination 83/225
# Parameters: {'blur_kernel': 3, 'custom_thresh': 200, 'morph_kernel': 3, 'dilate_iter': 2}
#   Precision: 0.0128
#   Recall: 0.0035
#   F1 Score: 0.0053
#   Jaccard: 0.0026
#
# Processing Combination 84/225
# Parameters: {'blur_kernel': 3, 'custom_thresh': 200, 'morph_kernel': 3, 'dilate_iter': 3}
#   Precision: 0.0137
#   Recall: 0.0038
#   F1 Score: 0.0057
#   Jaccard: 0.0029
#
# Processing Combination 85/225
# Parameters: {'blur_kernel': 3, 'custom_thresh': 200, 'morph_kernel': 5, 'dilate_iter': 1}
#   Precision: 0.0128
#   Recall: 0.0035
#   F1 Score: 0.0053
#   Jaccard: 0.0026
#
# Processing Combination 86/225
# Parameters: {'blur_kernel': 3, 'custom_thresh': 200, 'morph_kernel': 5, 'dilate_iter': 2}
#   Precision: 0.0128
#   Recall: 0.0035
#   F1 Score: 0.0053
#   Jaccard: 0.0026
#
# Processing Combination 87/225
# Parameters: {'blur_kernel': 3, 'custom_thresh': 200, 'morph_kernel': 5, 'dilate_iter': 3}
#   Precision: 0.0128
#   Recall: 0.0035
#   F1 Score: 0.0053
#   Jaccard: 0.0026
#
# Processing Combination 88/225
# Parameters: {'blur_kernel': 3, 'custom_thresh': 200, 'morph_kernel': 7, 'dilate_iter': 1}
#   Precision: 0.0128
#   Recall: 0.0035
#   F1 Score: 0.0053
#   Jaccard: 0.0026
#
# Processing Combination 89/225
# Parameters: {'blur_kernel': 3, 'custom_thresh': 200, 'morph_kernel': 7, 'dilate_iter': 2}
#   Precision: 0.0128
#   Recall: 0.0035
#   F1 Score: 0.0053
#   Jaccard: 0.0026
#
# Processing Combination 90/225
# Parameters: {'blur_kernel': 3, 'custom_thresh': 200, 'morph_kernel': 7, 'dilate_iter': 3}
#   Precision: 0.0128
#   Recall: 0.0035
#   F1 Score: 0.0053
#   Jaccard: 0.0026
#
# Processing Combination 91/225
# Parameters: {'blur_kernel': 5, 'custom_thresh': 50, 'morph_kernel': 3, 'dilate_iter': 1}
#   Precision: 0.0128
#   Recall: 0.0035
#   F1 Score: 0.0053
#   Jaccard: 0.0026
#
# Processing Combination 92/225
# Parameters: {'blur_kernel': 5, 'custom_thresh': 50, 'morph_kernel': 3, 'dilate_iter': 2}
#   Precision: 0.0128
#   Recall: 0.0035
#   F1 Score: 0.0053
#   Jaccard: 0.0026
#
# Processing Combination 93/225
# Parameters: {'blur_kernel': 5, 'custom_thresh': 50, 'morph_kernel': 3, 'dilate_iter': 3}
#   Precision: 0.0128
#   Recall: 0.0035
#   F1 Score: 0.0053
#   Jaccard: 0.0026
#
# Processing Combination 94/225
# Parameters: {'blur_kernel': 5, 'custom_thresh': 50, 'morph_kernel': 5, 'dilate_iter': 1}
#   Precision: 0.0128
#   Recall: 0.0035
#   F1 Score: 0.0053
#   Jaccard: 0.0026
#
# Processing Combination 95/225
# Parameters: {'blur_kernel': 5, 'custom_thresh': 50, 'morph_kernel': 5, 'dilate_iter': 2}
#   Precision: 0.0128
#   Recall: 0.0035
#   F1 Score: 0.0053
#   Jaccard: 0.0026
#
# Processing Combination 96/225
# Parameters: {'blur_kernel': 5, 'custom_thresh': 50, 'morph_kernel': 5, 'dilate_iter': 3}
#   Precision: 0.0128
#   Recall: 0.0035
#   F1 Score: 0.0053
#   Jaccard: 0.0026
#
# Processing Combination 97/225
# Parameters: {'blur_kernel': 5, 'custom_thresh': 50, 'morph_kernel': 7, 'dilate_iter': 1}
#   Precision: 0.0128
#   Recall: 0.0035
#   F1 Score: 0.0053
#   Jaccard: 0.0026
#
# Processing Combination 98/225
# Parameters: {'blur_kernel': 5, 'custom_thresh': 50, 'morph_kernel': 7, 'dilate_iter': 2}
#   Precision: 0.0128
#   Recall: 0.0035
#   F1 Score: 0.0053
#   Jaccard: 0.0026
#
# Processing Combination 99/225
# Parameters: {'blur_kernel': 5, 'custom_thresh': 50, 'morph_kernel': 7, 'dilate_iter': 3}
#   Precision: 0.0128
#   Recall: 0.0035
#   F1 Score: 0.0053
#   Jaccard: 0.0026
#
# Processing Combination 100/225
# Parameters: {'blur_kernel': 5, 'custom_thresh': 100, 'morph_kernel': 3, 'dilate_iter': 1}
#   Precision: 0.0677
#   Recall: 0.0287
#   F1 Score: 0.0390
#   Jaccard: 0.0205
#
# Processing Combination 101/225
# Parameters: {'blur_kernel': 5, 'custom_thresh': 100, 'morph_kernel': 3, 'dilate_iter': 2}
#   Precision: 0.0486
#   Recall: 0.0189
#   F1 Score: 0.0262
#   Jaccard: 0.0137
#
# Processing Combination 102/225
# Parameters: {'blur_kernel': 5, 'custom_thresh': 100, 'morph_kernel': 3, 'dilate_iter': 3}
#   Precision: 0.0275
#   Recall: 0.0094
#   F1 Score: 0.0132
#   Jaccard: 0.0068
#
# Processing Combination 103/225
# Parameters: {'blur_kernel': 5, 'custom_thresh': 100, 'morph_kernel': 5, 'dilate_iter': 1}
#   Precision: 0.0487
#   Recall: 0.0189
#   F1 Score: 0.0262
#   Jaccard: 0.0137
#
# Processing Combination 104/225
# Parameters: {'blur_kernel': 5, 'custom_thresh': 100, 'morph_kernel': 5, 'dilate_iter': 2}
#   Precision: 0.0200
#   Recall: 0.0063
#   F1 Score: 0.0091
#   Jaccard: 0.0046
#
# Processing Combination 105/225
# Parameters: {'blur_kernel': 5, 'custom_thresh': 100, 'morph_kernel': 5, 'dilate_iter': 3}
#   Precision: 0.0147
#   Recall: 0.0040
#   F1 Score: 0.0060
#   Jaccard: 0.0030
#
# Processing Combination 106/225
# Parameters: {'blur_kernel': 5, 'custom_thresh': 100, 'morph_kernel': 7, 'dilate_iter': 1}
#   Precision: 0.0328
#   Recall: 0.0115
#   F1 Score: 0.0161
#   Jaccard: 0.0084
#
# Processing Combination 107/225
# Parameters: {'blur_kernel': 5, 'custom_thresh': 100, 'morph_kernel': 7, 'dilate_iter': 2}
#   Precision: 0.0128
#   Recall: 0.0035
#   F1 Score: 0.0053
#   Jaccard: 0.0026
#
# Processing Combination 108/225
# Parameters: {'blur_kernel': 5, 'custom_thresh': 100, 'morph_kernel': 7, 'dilate_iter': 3}
#   Precision: 0.0128
#   Recall: 0.0035
#   F1 Score: 0.0053
#   Jaccard: 0.0026
#
# Processing Combination 109/225
# Parameters: {'blur_kernel': 5, 'custom_thresh': 127, 'morph_kernel': 3, 'dilate_iter': 1}
#   Precision: 0.0910
#   Recall: 0.0643
#   F1 Score: 0.0705
#   Jaccard: 0.0370
#
# Processing Combination 110/225
# Parameters: {'blur_kernel': 5, 'custom_thresh': 127, 'morph_kernel': 3, 'dilate_iter': 2}
#   Precision: 0.0841
#   Recall: 0.0525
#   F1 Score: 0.0606
#   Jaccard: 0.0318
#
# Processing Combination 111/225
# Parameters: {'blur_kernel': 5, 'custom_thresh': 127, 'morph_kernel': 3, 'dilate_iter': 3}
#   Precision: 0.0775
#   Recall: 0.0465
#   F1 Score: 0.0554
#   Jaccard: 0.0292
#
# Processing Combination 112/225
# Parameters: {'blur_kernel': 5, 'custom_thresh': 127, 'morph_kernel': 5, 'dilate_iter': 1}
#   Precision: 0.0875
#   Recall: 0.0528
#   F1 Score: 0.0623
#   Jaccard: 0.0327
#
# Processing Combination 113/225
# Parameters: {'blur_kernel': 5, 'custom_thresh': 127, 'morph_kernel': 5, 'dilate_iter': 2}
#   Precision: 0.0700
#   Recall: 0.0392
#   F1 Score: 0.0477
#   Jaccard: 0.0250
#
# Processing Combination 114/225
# Parameters: {'blur_kernel': 5, 'custom_thresh': 127, 'morph_kernel': 5, 'dilate_iter': 3}
#   Precision: 0.0505
#   Recall: 0.0270
#   F1 Score: 0.0333
#   Jaccard: 0.0174
#
# Processing Combination 115/225
# Parameters: {'blur_kernel': 5, 'custom_thresh': 127, 'morph_kernel': 7, 'dilate_iter': 1}
#   Precision: 0.0855
#   Recall: 0.0491
#   F1 Score: 0.0592
#   Jaccard: 0.0312
#
# Processing Combination 116/225
# Parameters: {'blur_kernel': 5, 'custom_thresh': 127, 'morph_kernel': 7, 'dilate_iter': 2}
#   Precision: 0.0586
#   Recall: 0.0310
#   F1 Score: 0.0384
#   Jaccard: 0.0201
#
# Processing Combination 117/225
# Parameters: {'blur_kernel': 5, 'custom_thresh': 127, 'morph_kernel': 7, 'dilate_iter': 3}
#   Precision: 0.0367
#   Recall: 0.0175
#   F1 Score: 0.0224
#   Jaccard: 0.0116
#
# Processing Combination 118/225
# Parameters: {'blur_kernel': 5, 'custom_thresh': 150, 'morph_kernel': 3, 'dilate_iter': 1}
#   Precision: 0.0456
#   Recall: 0.0296
#   F1 Score: 0.0318
#   Jaccard: 0.0165
#
# Processing Combination 119/225
# Parameters: {'blur_kernel': 5, 'custom_thresh': 150, 'morph_kernel': 3, 'dilate_iter': 2}
#   Precision: 0.0567
#   Recall: 0.0332
#   F1 Score: 0.0382
#   Jaccard: 0.0200
#
# Processing Combination 120/225
# Parameters: {'blur_kernel': 5, 'custom_thresh': 150, 'morph_kernel': 3, 'dilate_iter': 3}
#   Precision: 0.0568
#   Recall: 0.0309
#   F1 Score: 0.0366
#   Jaccard: 0.0191
#
# Processing Combination 121/225
# Parameters: {'blur_kernel': 5, 'custom_thresh': 150, 'morph_kernel': 5, 'dilate_iter': 1}
#   Precision: 0.0408
#   Recall: 0.0239
#   F1 Score: 0.0273
#   Jaccard: 0.0142
#
# Processing Combination 122/225
# Parameters: {'blur_kernel': 5, 'custom_thresh': 150, 'morph_kernel': 5, 'dilate_iter': 2}
#   Precision: 0.0410
#   Recall: 0.0226
#   F1 Score: 0.0269
#   Jaccard: 0.0140
#
# Processing Combination 123/225
# Parameters: {'blur_kernel': 5, 'custom_thresh': 150, 'morph_kernel': 5, 'dilate_iter': 3}
#   Precision: 0.0420
#   Recall: 0.0220
#   F1 Score: 0.0272
#   Jaccard: 0.0142
#
# Processing Combination 124/225
# Parameters: {'blur_kernel': 5, 'custom_thresh': 150, 'morph_kernel': 7, 'dilate_iter': 1}
#   Precision: 0.0361
#   Recall: 0.0195
#   F1 Score: 0.0229
#   Jaccard: 0.0119
#
# Processing Combination 125/225
# Parameters: {'blur_kernel': 5, 'custom_thresh': 150, 'morph_kernel': 7, 'dilate_iter': 2}
#   Precision: 0.0340
#   Recall: 0.0176
#   F1 Score: 0.0215
#   Jaccard: 0.0112
#
# Processing Combination 126/225
# Parameters: {'blur_kernel': 5, 'custom_thresh': 150, 'morph_kernel': 7, 'dilate_iter': 3}
#   Precision: 0.0298
#   Recall: 0.0153
#   F1 Score: 0.0189
#   Jaccard: 0.0098
#
# Processing Combination 127/225
# Parameters: {'blur_kernel': 5, 'custom_thresh': 200, 'morph_kernel': 3, 'dilate_iter': 1}
#   Precision: 0.0128
#   Recall: 0.0035
#   F1 Score: 0.0053
#   Jaccard: 0.0026
#
# Processing Combination 128/225
# Parameters: {'blur_kernel': 5, 'custom_thresh': 200, 'morph_kernel': 3, 'dilate_iter': 2}
#   Precision: 0.0128
#   Recall: 0.0035
#   F1 Score: 0.0053
#   Jaccard: 0.0026
#
# Processing Combination 129/225
# Parameters: {'blur_kernel': 5, 'custom_thresh': 200, 'morph_kernel': 3, 'dilate_iter': 3}
#   Precision: 0.0128
#   Recall: 0.0035
#   F1 Score: 0.0053
#   Jaccard: 0.0026
#
# Processing Combination 130/225
# Parameters: {'blur_kernel': 5, 'custom_thresh': 200, 'morph_kernel': 5, 'dilate_iter': 1}
#   Precision: 0.0128
#   Recall: 0.0035
#   F1 Score: 0.0053
#   Jaccard: 0.0026
#
# Processing Combination 131/225
# Parameters: {'blur_kernel': 5, 'custom_thresh': 200, 'morph_kernel': 5, 'dilate_iter': 2}
#   Precision: 0.0128
#   Recall: 0.0035
#   F1 Score: 0.0053
#   Jaccard: 0.0026
#
# Processing Combination 132/225
# Parameters: {'blur_kernel': 5, 'custom_thresh': 200, 'morph_kernel': 5, 'dilate_iter': 3}
#   Precision: 0.0128
#   Recall: 0.0035
#   F1 Score: 0.0053
#   Jaccard: 0.0026
#
# Processing Combination 133/225
# Parameters: {'blur_kernel': 5, 'custom_thresh': 200, 'morph_kernel': 7, 'dilate_iter': 1}
#   Precision: 0.0128
#   Recall: 0.0035
#   F1 Score: 0.0053
#   Jaccard: 0.0026
#
# Processing Combination 134/225
# Parameters: {'blur_kernel': 5, 'custom_thresh': 200, 'morph_kernel': 7, 'dilate_iter': 2}
#   Precision: 0.0128
#   Recall: 0.0035
#   F1 Score: 0.0053
#   Jaccard: 0.0026
#
# Processing Combination 135/225
# Parameters: {'blur_kernel': 5, 'custom_thresh': 200, 'morph_kernel': 7, 'dilate_iter': 3}
#   Precision: 0.0128
#   Recall: 0.0035
#   F1 Score: 0.0053
#   Jaccard: 0.0026
#
# Processing Combination 136/225
# Parameters: {'blur_kernel': 7, 'custom_thresh': 50, 'morph_kernel': 3, 'dilate_iter': 1}
#   Precision: 0.0128
#   Recall: 0.0035
#   F1 Score: 0.0053
#   Jaccard: 0.0026
#
# Processing Combination 137/225
# Parameters: {'blur_kernel': 7, 'custom_thresh': 50, 'morph_kernel': 3, 'dilate_iter': 2}
#   Precision: 0.0128
#   Recall: 0.0035
#   F1 Score: 0.0053
#   Jaccard: 0.0026
#
# Processing Combination 138/225
# Parameters: {'blur_kernel': 7, 'custom_thresh': 50, 'morph_kernel': 3, 'dilate_iter': 3}
#   Precision: 0.0128
#   Recall: 0.0035
#   F1 Score: 0.0053
#   Jaccard: 0.0026
#
# Processing Combination 139/225
# Parameters: {'blur_kernel': 7, 'custom_thresh': 50, 'morph_kernel': 5, 'dilate_iter': 1}
#   Precision: 0.0128
#   Recall: 0.0035
#   F1 Score: 0.0053
#   Jaccard: 0.0026
#
# Processing Combination 140/225
# Parameters: {'blur_kernel': 7, 'custom_thresh': 50, 'morph_kernel': 5, 'dilate_iter': 2}
#   Precision: 0.0128
#   Recall: 0.0035
#   F1 Score: 0.0053
#   Jaccard: 0.0026
#
# Processing Combination 141/225
# Parameters: {'blur_kernel': 7, 'custom_thresh': 50, 'morph_kernel': 5, 'dilate_iter': 3}
#   Precision: 0.0128
#   Recall: 0.0035
#   F1 Score: 0.0053
#   Jaccard: 0.0026
#
# Processing Combination 142/225
# Parameters: {'blur_kernel': 7, 'custom_thresh': 50, 'morph_kernel': 7, 'dilate_iter': 1}
#   Precision: 0.0128
#   Recall: 0.0035
#   F1 Score: 0.0053
#   Jaccard: 0.0026
#
# Processing Combination 143/225
# Parameters: {'blur_kernel': 7, 'custom_thresh': 50, 'morph_kernel': 7, 'dilate_iter': 2}
#   Precision: 0.0128
#   Recall: 0.0035
#   F1 Score: 0.0053
#   Jaccard: 0.0026
#
# Processing Combination 144/225
# Parameters: {'blur_kernel': 7, 'custom_thresh': 50, 'morph_kernel': 7, 'dilate_iter': 3}
#   Precision: 0.0128
#   Recall: 0.0035
#   F1 Score: 0.0053
#   Jaccard: 0.0026
#
# Processing Combination 145/225
# Parameters: {'blur_kernel': 7, 'custom_thresh': 100, 'morph_kernel': 3, 'dilate_iter': 1}
#   Precision: 0.0517
#   Recall: 0.0208
#   F1 Score: 0.0286
#   Jaccard: 0.0149
#
# Processing Combination 146/225
# Parameters: {'blur_kernel': 7, 'custom_thresh': 100, 'morph_kernel': 3, 'dilate_iter': 2}
#   Precision: 0.0429
#   Recall: 0.0167
#   F1 Score: 0.0230
#   Jaccard: 0.0120
#
# Processing Combination 147/225
# Parameters: {'blur_kernel': 7, 'custom_thresh': 100, 'morph_kernel': 3, 'dilate_iter': 3}
#   Precision: 0.0259
#   Recall: 0.0092
#   F1 Score: 0.0129
#   Jaccard: 0.0066
#
# Processing Combination 148/225
# Parameters: {'blur_kernel': 7, 'custom_thresh': 100, 'morph_kernel': 5, 'dilate_iter': 1}
#   Precision: 0.0429
#   Recall: 0.0167
#   F1 Score: 0.0230
#   Jaccard: 0.0120
#
# Processing Combination 149/225
# Parameters: {'blur_kernel': 7, 'custom_thresh': 100, 'morph_kernel': 5, 'dilate_iter': 2}
#   Precision: 0.0163
#   Recall: 0.0051
#   F1 Score: 0.0073
#   Jaccard: 0.0037
#
# Processing Combination 150/225
# Parameters: {'blur_kernel': 7, 'custom_thresh': 100, 'morph_kernel': 5, 'dilate_iter': 3}
#   Precision: 0.0128
#   Recall: 0.0035
#   F1 Score: 0.0053
#   Jaccard: 0.0026
#
# Processing Combination 151/225
# Parameters: {'blur_kernel': 7, 'custom_thresh': 100, 'morph_kernel': 7, 'dilate_iter': 1}
#   Precision: 0.0260
#   Recall: 0.0095
#   F1 Score: 0.0132
#   Jaccard: 0.0068
#
# Processing Combination 152/225
# Parameters: {'blur_kernel': 7, 'custom_thresh': 100, 'morph_kernel': 7, 'dilate_iter': 2}
#   Precision: 0.0132
#   Recall: 0.0037
#   F1 Score: 0.0056
#   Jaccard: 0.0028
#
# Processing Combination 153/225
# Parameters: {'blur_kernel': 7, 'custom_thresh': 100, 'morph_kernel': 7, 'dilate_iter': 3}
#   Precision: 0.0128
#   Recall: 0.0035
#   F1 Score: 0.0053
#   Jaccard: 0.0026
#
# Processing Combination 154/225
# Parameters: {'blur_kernel': 7, 'custom_thresh': 127, 'morph_kernel': 3, 'dilate_iter': 1}
#   Precision: 0.0897
#   Recall: 0.0566
#   F1 Score: 0.0657
#   Jaccard: 0.0346
#
# Processing Combination 155/225
# Parameters: {'blur_kernel': 7, 'custom_thresh': 127, 'morph_kernel': 3, 'dilate_iter': 2}
#   Precision: 0.0889
#   Recall: 0.0542
#   F1 Score: 0.0636
#   Jaccard: 0.0334
#
# Processing Combination 156/225
# Parameters: {'blur_kernel': 7, 'custom_thresh': 127, 'morph_kernel': 3, 'dilate_iter': 3}
#   Precision: 0.0826
#   Recall: 0.0483
#   F1 Score: 0.0582
#   Jaccard: 0.0307
#
# Processing Combination 157/225
# Parameters: {'blur_kernel': 7, 'custom_thresh': 127, 'morph_kernel': 5, 'dilate_iter': 1}
#   Precision: 0.0891
#   Recall: 0.0538
#   F1 Score: 0.0635
#   Jaccard: 0.0334
#
# Processing Combination 158/225
# Parameters: {'blur_kernel': 7, 'custom_thresh': 127, 'morph_kernel': 5, 'dilate_iter': 2}
#   Precision: 0.0737
#   Recall: 0.0409
#   F1 Score: 0.0498
#   Jaccard: 0.0262
#
# Processing Combination 159/225
# Parameters: {'blur_kernel': 7, 'custom_thresh': 127, 'morph_kernel': 5, 'dilate_iter': 3}
#   Precision: 0.0528
#   Recall: 0.0278
#   F1 Score: 0.0346
#   Jaccard: 0.0181
#
# Processing Combination 160/225
# Parameters: {'blur_kernel': 7, 'custom_thresh': 127, 'morph_kernel': 7, 'dilate_iter': 1}
#   Precision: 0.0840
#   Recall: 0.0480
#   F1 Score: 0.0584
#   Jaccard: 0.0308
#
# Processing Combination 161/225
# Parameters: {'blur_kernel': 7, 'custom_thresh': 127, 'morph_kernel': 7, 'dilate_iter': 2}
#   Precision: 0.0552
#   Recall: 0.0292
#   F1 Score: 0.0366
#   Jaccard: 0.0192
#
# Processing Combination 162/225
# Parameters: {'blur_kernel': 7, 'custom_thresh': 127, 'morph_kernel': 7, 'dilate_iter': 3}
#   Precision: 0.0414
#   Recall: 0.0192
#   F1 Score: 0.0249
#   Jaccard: 0.0130
#
# Processing Combination 163/225
# Parameters: {'blur_kernel': 7, 'custom_thresh': 150, 'morph_kernel': 3, 'dilate_iter': 1}
#   Precision: 0.0375
#   Recall: 0.0228
#   F1 Score: 0.0253
#   Jaccard: 0.0131
#
# Processing Combination 164/225
# Parameters: {'blur_kernel': 7, 'custom_thresh': 150, 'morph_kernel': 3, 'dilate_iter': 2}
#   Precision: 0.0436
#   Recall: 0.0260
#   F1 Score: 0.0297
#   Jaccard: 0.0155
#
# Processing Combination 165/225
# Parameters: {'blur_kernel': 7, 'custom_thresh': 150, 'morph_kernel': 3, 'dilate_iter': 3}
#   Precision: 0.0460
#   Recall: 0.0252
#   F1 Score: 0.0301
#   Jaccard: 0.0157
#
# Processing Combination 166/225
# Parameters: {'blur_kernel': 7, 'custom_thresh': 150, 'morph_kernel': 5, 'dilate_iter': 1}
#   Precision: 0.0404
#   Recall: 0.0231
#   F1 Score: 0.0266
#   Jaccard: 0.0139
#
# Processing Combination 167/225
# Parameters: {'blur_kernel': 7, 'custom_thresh': 150, 'morph_kernel': 5, 'dilate_iter': 2}
#   Precision: 0.0402
#   Recall: 0.0212
#   F1 Score: 0.0255
#   Jaccard: 0.0133
#
# Processing Combination 168/225
# Parameters: {'blur_kernel': 7, 'custom_thresh': 150, 'morph_kernel': 5, 'dilate_iter': 3}
#   Precision: 0.0368
#   Recall: 0.0187
#   F1 Score: 0.0233
#   Jaccard: 0.0121
#
# Processing Combination 169/225
# Parameters: {'blur_kernel': 7, 'custom_thresh': 150, 'morph_kernel': 7, 'dilate_iter': 1}
#   Precision: 0.0365
#   Recall: 0.0191
#   F1 Score: 0.0227
#   Jaccard: 0.0118
#
# Processing Combination 170/225
# Parameters: {'blur_kernel': 7, 'custom_thresh': 150, 'morph_kernel': 7, 'dilate_iter': 2}
#   Precision: 0.0338
#   Recall: 0.0165
#   F1 Score: 0.0207
#   Jaccard: 0.0108
#
# Processing Combination 171/225
# Parameters: {'blur_kernel': 7, 'custom_thresh': 150, 'morph_kernel': 7, 'dilate_iter': 3}
#   Precision: 0.0325
#   Recall: 0.0151
#   F1 Score: 0.0193
#   Jaccard: 0.0100
#
# Processing Combination 172/225
# Parameters: {'blur_kernel': 7, 'custom_thresh': 200, 'morph_kernel': 3, 'dilate_iter': 1}
#   Precision: 0.0128
#   Recall: 0.0035
#   F1 Score: 0.0053
#   Jaccard: 0.0026
#
# Processing Combination 173/225
# Parameters: {'blur_kernel': 7, 'custom_thresh': 200, 'morph_kernel': 3, 'dilate_iter': 2}
#   Precision: 0.0128
#   Recall: 0.0035
#   F1 Score: 0.0053
#   Jaccard: 0.0026
#
# Processing Combination 174/225
# Parameters: {'blur_kernel': 7, 'custom_thresh': 200, 'morph_kernel': 3, 'dilate_iter': 3}
#   Precision: 0.0128
#   Recall: 0.0035
#   F1 Score: 0.0053
#   Jaccard: 0.0026
#
# Processing Combination 175/225
# Parameters: {'blur_kernel': 7, 'custom_thresh': 200, 'morph_kernel': 5, 'dilate_iter': 1}
#   Precision: 0.0128
#   Recall: 0.0035
#   F1 Score: 0.0053
#   Jaccard: 0.0026
#
# Processing Combination 176/225
# Parameters: {'blur_kernel': 7, 'custom_thresh': 200, 'morph_kernel': 5, 'dilate_iter': 2}
#   Precision: 0.0128
#   Recall: 0.0035
#   F1 Score: 0.0053
#   Jaccard: 0.0026
#
# Processing Combination 177/225
# Parameters: {'blur_kernel': 7, 'custom_thresh': 200, 'morph_kernel': 5, 'dilate_iter': 3}
#   Precision: 0.0128
#   Recall: 0.0035
#   F1 Score: 0.0053
#   Jaccard: 0.0026
#
# Processing Combination 178/225
# Parameters: {'blur_kernel': 7, 'custom_thresh': 200, 'morph_kernel': 7, 'dilate_iter': 1}
#   Precision: 0.0128
#   Recall: 0.0035
#   F1 Score: 0.0053
#   Jaccard: 0.0026
#
# Processing Combination 179/225
# Parameters: {'blur_kernel': 7, 'custom_thresh': 200, 'morph_kernel': 7, 'dilate_iter': 2}
#   Precision: 0.0128
#   Recall: 0.0035
#   F1 Score: 0.0053
#   Jaccard: 0.0026
#
# Processing Combination 180/225
# Parameters: {'blur_kernel': 7, 'custom_thresh': 200, 'morph_kernel': 7, 'dilate_iter': 3}
#   Precision: 0.0128
#   Recall: 0.0035
#   F1 Score: 0.0053
#   Jaccard: 0.0026
#
# Processing Combination 181/225
# Parameters: {'blur_kernel': 9, 'custom_thresh': 50, 'morph_kernel': 3, 'dilate_iter': 1}
#   Precision: 0.0128
#   Recall: 0.0035
#   F1 Score: 0.0053
#   Jaccard: 0.0026
#
# Processing Combination 182/225
# Parameters: {'blur_kernel': 9, 'custom_thresh': 50, 'morph_kernel': 3, 'dilate_iter': 2}
#   Precision: 0.0128
#   Recall: 0.0035
#   F1 Score: 0.0053
#   Jaccard: 0.0026
#
# Processing Combination 183/225
# Parameters: {'blur_kernel': 9, 'custom_thresh': 50, 'morph_kernel': 3, 'dilate_iter': 3}
#   Precision: 0.0128
#   Recall: 0.0035
#   F1 Score: 0.0053
#   Jaccard: 0.0026
#
# Processing Combination 184/225
# Parameters: {'blur_kernel': 9, 'custom_thresh': 50, 'morph_kernel': 5, 'dilate_iter': 1}
#   Precision: 0.0128
#   Recall: 0.0035
#   F1 Score: 0.0053
#   Jaccard: 0.0026
#
# Processing Combination 185/225
# Parameters: {'blur_kernel': 9, 'custom_thresh': 50, 'morph_kernel': 5, 'dilate_iter': 2}
#   Precision: 0.0128
#   Recall: 0.0035
#   F1 Score: 0.0053
#   Jaccard: 0.0026
#
# Processing Combination 186/225
# Parameters: {'blur_kernel': 9, 'custom_thresh': 50, 'morph_kernel': 5, 'dilate_iter': 3}
#   Precision: 0.0128
#   Recall: 0.0035
#   F1 Score: 0.0053
#   Jaccard: 0.0026
#
# Processing Combination 187/225
# Parameters: {'blur_kernel': 9, 'custom_thresh': 50, 'morph_kernel': 7, 'dilate_iter': 1}
#   Precision: 0.0128
#   Recall: 0.0035
#   F1 Score: 0.0053
#   Jaccard: 0.0026
#
# Processing Combination 188/225
# Parameters: {'blur_kernel': 9, 'custom_thresh': 50, 'morph_kernel': 7, 'dilate_iter': 2}
#   Precision: 0.0128
#   Recall: 0.0035
#   F1 Score: 0.0053
#   Jaccard: 0.0026
#
# Processing Combination 189/225
# Parameters: {'blur_kernel': 9, 'custom_thresh': 50, 'morph_kernel': 7, 'dilate_iter': 3}
#   Precision: 0.0128
#   Recall: 0.0035
#   F1 Score: 0.0053
#   Jaccard: 0.0026
#
# Processing Combination 190/225
# Parameters: {'blur_kernel': 9, 'custom_thresh': 100, 'morph_kernel': 3, 'dilate_iter': 1}
#   Precision: 0.0461
#   Recall: 0.0180
#   F1 Score: 0.0248
#   Jaccard: 0.0130
#
# Processing Combination 191/225
# Parameters: {'blur_kernel': 9, 'custom_thresh': 100, 'morph_kernel': 3, 'dilate_iter': 2}
#   Precision: 0.0334
#   Recall: 0.0132
#   F1 Score: 0.0180
#   Jaccard: 0.0093
#
# Processing Combination 192/225
# Parameters: {'blur_kernel': 9, 'custom_thresh': 100, 'morph_kernel': 3, 'dilate_iter': 3}
#   Precision: 0.0215
#   Recall: 0.0066
#   F1 Score: 0.0096
#   Jaccard: 0.0049
#
# Processing Combination 193/225
# Parameters: {'blur_kernel': 9, 'custom_thresh': 100, 'morph_kernel': 5, 'dilate_iter': 1}
#   Precision: 0.0334
#   Recall: 0.0132
#   F1 Score: 0.0179
#   Jaccard: 0.0093
#
# Processing Combination 194/225
# Parameters: {'blur_kernel': 9, 'custom_thresh': 100, 'morph_kernel': 5, 'dilate_iter': 2}
#   Precision: 0.0170
#   Recall: 0.0053
#   F1 Score: 0.0075
#   Jaccard: 0.0038
#
# Processing Combination 195/225
# Parameters: {'blur_kernel': 9, 'custom_thresh': 100, 'morph_kernel': 5, 'dilate_iter': 3}
#   Precision: 0.0128
#   Recall: 0.0035
#   F1 Score: 0.0053
#   Jaccard: 0.0026
#
# Processing Combination 196/225
# Parameters: {'blur_kernel': 9, 'custom_thresh': 100, 'morph_kernel': 7, 'dilate_iter': 1}
#   Precision: 0.0220
#   Recall: 0.0069
#   F1 Score: 0.0100
#   Jaccard: 0.0051
#
# Processing Combination 197/225
# Parameters: {'blur_kernel': 9, 'custom_thresh': 100, 'morph_kernel': 7, 'dilate_iter': 2}
#   Precision: 0.0128
#   Recall: 0.0035
#   F1 Score: 0.0053
#   Jaccard: 0.0026
#
# Processing Combination 198/225
# Parameters: {'blur_kernel': 9, 'custom_thresh': 100, 'morph_kernel': 7, 'dilate_iter': 3}
#   Precision: 0.0128
#   Recall: 0.0035
#   F1 Score: 0.0053
#   Jaccard: 0.0026
#
# Processing Combination 199/225
# Parameters: {'blur_kernel': 9, 'custom_thresh': 127, 'morph_kernel': 3, 'dilate_iter': 1}
#   Precision: 0.0926
#   Recall: 0.0550
#   F1 Score: 0.0657
#   Jaccard: 0.0346
#
# Processing Combination 200/225
# Parameters: {'blur_kernel': 9, 'custom_thresh': 127, 'morph_kernel': 3, 'dilate_iter': 2}
#   Precision: 0.0913
#   Recall: 0.0539
#   F1 Score: 0.0646
#   Jaccard: 0.0340
#
# Processing Combination 201/225
# Parameters: {'blur_kernel': 9, 'custom_thresh': 127, 'morph_kernel': 3, 'dilate_iter': 3}
#   Precision: 0.0817
#   Recall: 0.0467
#   F1 Score: 0.0566
#   Jaccard: 0.0298
#
# Processing Combination 202/225
# Parameters: {'blur_kernel': 9, 'custom_thresh': 127, 'morph_kernel': 5, 'dilate_iter': 1}
#   Precision: 0.0909
#   Recall: 0.0530
#   F1 Score: 0.0639
#   Jaccard: 0.0337
#
# Processing Combination 203/225
# Parameters: {'blur_kernel': 9, 'custom_thresh': 127, 'morph_kernel': 5, 'dilate_iter': 2}
#   Precision: 0.0716
#   Recall: 0.0397
#   F1 Score: 0.0488
#   Jaccard: 0.0256
#
# Processing Combination 204/225
# Parameters: {'blur_kernel': 9, 'custom_thresh': 127, 'morph_kernel': 5, 'dilate_iter': 3}
#   Precision: 0.0560
#   Recall: 0.0286
#   F1 Score: 0.0362
#   Jaccard: 0.0190
#
# Processing Combination 205/225
# Parameters: {'blur_kernel': 9, 'custom_thresh': 127, 'morph_kernel': 7, 'dilate_iter': 1}
#   Precision: 0.0799
#   Recall: 0.0455
#   F1 Score: 0.0552
#   Jaccard: 0.0291
#
# Processing Combination 206/225
# Parameters: {'blur_kernel': 9, 'custom_thresh': 127, 'morph_kernel': 7, 'dilate_iter': 2}
#   Precision: 0.0567
#   Recall: 0.0294
#   F1 Score: 0.0372
#   Jaccard: 0.0195
#
# Processing Combination 207/225
# Parameters: {'blur_kernel': 9, 'custom_thresh': 127, 'morph_kernel': 7, 'dilate_iter': 3}
#   Precision: 0.0426
#   Recall: 0.0185
#   F1 Score: 0.0246
#   Jaccard: 0.0127
#
# Processing Combination 208/225
# Parameters: {'blur_kernel': 9, 'custom_thresh': 150, 'morph_kernel': 3, 'dilate_iter': 1}
#   Precision: 0.0393
#   Recall: 0.0221
#   F1 Score: 0.0257
#   Jaccard: 0.0134
#
# Processing Combination 209/225
# Parameters: {'blur_kernel': 9, 'custom_thresh': 150, 'morph_kernel': 3, 'dilate_iter': 2}
#   Precision: 0.0409
#   Recall: 0.0232
#   F1 Score: 0.0271
#   Jaccard: 0.0141
#
# Processing Combination 210/225
# Parameters: {'blur_kernel': 9, 'custom_thresh': 150, 'morph_kernel': 3, 'dilate_iter': 3}
#   Precision: 0.0399
#   Recall: 0.0211
#   F1 Score: 0.0254
#   Jaccard: 0.0132
#
# Processing Combination 211/225
# Parameters: {'blur_kernel': 9, 'custom_thresh': 150, 'morph_kernel': 5, 'dilate_iter': 1}
#   Precision: 0.0390
#   Recall: 0.0219
#   F1 Score: 0.0256
#   Jaccard: 0.0133
#
# Processing Combination 212/225
# Parameters: {'blur_kernel': 9, 'custom_thresh': 150, 'morph_kernel': 5, 'dilate_iter': 2}
#   Precision: 0.0379
#   Recall: 0.0190
#   F1 Score: 0.0232
#   Jaccard: 0.0120
#
# Processing Combination 213/225
# Parameters: {'blur_kernel': 9, 'custom_thresh': 150, 'morph_kernel': 5, 'dilate_iter': 3}
#   Precision: 0.0361
#   Recall: 0.0177
#   F1 Score: 0.0223
#   Jaccard: 0.0116
#
# Processing Combination 214/225
# Parameters: {'blur_kernel': 9, 'custom_thresh': 150, 'morph_kernel': 7, 'dilate_iter': 1}
#   Precision: 0.0369
#   Recall: 0.0188
#   F1 Score: 0.0228
#   Jaccard: 0.0118
#
# Processing Combination 215/225
# Parameters: {'blur_kernel': 9, 'custom_thresh': 150, 'morph_kernel': 7, 'dilate_iter': 2}
#   Precision: 0.0348
#   Recall: 0.0175
#   F1 Score: 0.0219
#   Jaccard: 0.0114
#
# Processing Combination 216/225
# Parameters: {'blur_kernel': 9, 'custom_thresh': 150, 'morph_kernel': 7, 'dilate_iter': 3}
#   Precision: 0.0317
#   Recall: 0.0147
#   F1 Score: 0.0188
#   Jaccard: 0.0098
#
# Processing Combination 217/225
# Parameters: {'blur_kernel': 9, 'custom_thresh': 200, 'morph_kernel': 3, 'dilate_iter': 1}
#   Precision: 0.0128
#   Recall: 0.0035
#   F1 Score: 0.0053
#   Jaccard: 0.0026
#
# Processing Combination 218/225
# Parameters: {'blur_kernel': 9, 'custom_thresh': 200, 'morph_kernel': 3, 'dilate_iter': 2}
#   Precision: 0.0128
#   Recall: 0.0035
#   F1 Score: 0.0053
#   Jaccard: 0.0026
#
# Processing Combination 219/225
# Parameters: {'blur_kernel': 9, 'custom_thresh': 200, 'morph_kernel': 3, 'dilate_iter': 3}
#   Precision: 0.0128
#   Recall: 0.0035
#   F1 Score: 0.0053
#   Jaccard: 0.0026
#
# Processing Combination 220/225
# Parameters: {'blur_kernel': 9, 'custom_thresh': 200, 'morph_kernel': 5, 'dilate_iter': 1}
#   Precision: 0.0128
#   Recall: 0.0035
#   F1 Score: 0.0053
#   Jaccard: 0.0026
#
# Processing Combination 221/225
# Parameters: {'blur_kernel': 9, 'custom_thresh': 200, 'morph_kernel': 5, 'dilate_iter': 2}
#   Precision: 0.0128
#   Recall: 0.0035
#   F1 Score: 0.0053
#   Jaccard: 0.0026
#
# Processing Combination 222/225
# Parameters: {'blur_kernel': 9, 'custom_thresh': 200, 'morph_kernel': 5, 'dilate_iter': 3}
#   Precision: 0.0128
#   Recall: 0.0035
#   F1 Score: 0.0053
#   Jaccard: 0.0026
#
# Processing Combination 223/225
# Parameters: {'blur_kernel': 9, 'custom_thresh': 200, 'morph_kernel': 7, 'dilate_iter': 1}
#   Precision: 0.0128
#   Recall: 0.0035
#   F1 Score: 0.0053
#   Jaccard: 0.0026
#
# Processing Combination 224/225
# Parameters: {'blur_kernel': 9, 'custom_thresh': 200, 'morph_kernel': 7, 'dilate_iter': 2}
#   Precision: 0.0128
#   Recall: 0.0035
#   F1 Score: 0.0053
#   Jaccard: 0.0026
#
# Processing Combination 225/225
# Parameters: {'blur_kernel': 9, 'custom_thresh': 200, 'morph_kernel': 7, 'dilate_iter': 3}
#   Precision: 0.0128
#   Recall: 0.0035
#   F1 Score: 0.0053
#   Jaccard: 0.0026
#
# --- Top 10 Best Parameter Configurations ---
#  blur_kernel  custom_thresh  morph_kernel  dilate_iter  precision   recall  f1_score  jaccard
#            1            127             3            1   0.085161 0.075313  0.073151 0.038321
#            3            127             3            1   0.086777 0.068403  0.070769 0.037111
#            5            127             3            1   0.091034 0.064344  0.070521 0.037025
#            1            127             5            1   0.088690 0.062688  0.068252 0.035817
#            9            127             3            1   0.092629 0.055029  0.065739 0.034591
#            7            127             3            1   0.089713 0.056648  0.065702 0.034553
#            3            127             5            1   0.088371 0.056857  0.065594 0.034534
#            9            127             3            2   0.091321 0.053916  0.064560 0.034048
#            9            127             5            1   0.090932 0.053042  0.063898 0.033681
#            7            127             3            2   0.088855 0.054168  0.063564 0.033442
#
# --- Best Overall Parameter Configuration ---
# Blur Kernel: 1.0
# Custom Threshold: 127.0
# Morph Kernel: 3.0
# Dilate Iterations: 1.0
#
# Metrics:
#   Precision: 0.0852
#   Recall: 0.0753
#   F1 Score: 0.0732
#   Jaccard: 0.0383
